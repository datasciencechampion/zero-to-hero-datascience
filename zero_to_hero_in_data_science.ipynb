# %% [markdown]
# <a href="https://colab.research.google.com/github/datasciencechampion/zero-to-hero-datascience/blob/main/zero_to_hero_in_data_science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Welcome to **Zero-to-Hero in Data Science**,
#
# Why this course when we already have many such courses available on the internet ? Answer is here [**DataScienceChampion**](https://colab.research.google.com/drive/1RfaABYY9TbO5P0C_9Q8lLqnPAYx-X9us?usp=sharing)

# %% [markdown]
# # Without further ado , let's begin the journey of **Zero-to-Hero in Data Science**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# It is assumed that there will be two types of users who can make use of this course.
# - Somebody with no prior knowledge of Python and AI/ML can follow the topics in **top to bottom** manner where he/she will start with Python, Data Structure , Maths behind data science followed by Data Science basic to advance topics.
# - Somebody with some prior experiance in this domain can jump to the specific topic which he/she wants to learn.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Python**
#
# - [**Basics**](https://colab.research.google.com/drive/17IDwUznicCx06ToAlrAdeYTAOZM3W_Sm?usp=sharing)
#
# - [**Writing Custom Module & Creating Packages**](https://colab.research.google.com/drive/1CFFBErAIBSMOGXNL4kUchz4PWsfy4Gmk?usp=sharing)
#
# - [**Looping techniques**](https://colab.research.google.com/drive/1d5tIikxb5juipt9besPHQRXNh4_XbUCO?usp=sharing)
#
# # **Data Structure in Python**
#   - [**Concepts**](https://colab.research.google.com/drive/14QJmKicXNCP-HN6YHakfzakFTyx0KmBv?usp=sharing)
#
#   - [**Time & Space Complexity**](https://colab.research.google.com/drive/1qCmoFXHX181VFWk3Uj_BZQOG83hEWUUY?usp=sharing)
#
#   - [**Search Algorigthms**](https://colab.research.google.com/drive/1ZGQMVu4sfb08YtzmPoM2t2iZ46f3Vcyk?usp=sharing)

# %% [markdown]
# # **Math behind Data Science**
# Data Science and Machine Learning is powered by four important concepts of mathematics. They are : **Statistics, Linear Algebra, Probability**, and **Calculus**. While statistical concepts are the core part of every model, it's the **calculus** which helps the model **learn** and **optimize**.
#
# This section is still work in progess and many math concepts i am yet to add.
#  - [**Logarithm**](https://colab.research.google.com/drive/1bR0u6kS2xM5-3lYCNbDsqbq1OpD3bhKC?usp=sharing)
#
#  - [**Vector**](https://colab.research.google.com/drive/1kPxAVjoV1GMJjfEmTI7NiOdHmVSKr0xG?usp=sharing)

# %% [markdown]
# # **Data Science**
#
# - [**What is Data, Sample Data,  & Sample Collection Techniques**](https://colab.research.google.com/drive/1PpYf1ibRnw9oprzezdbwcTr4c63_V_M1?usp=sharing)
# - [**What is Data Science & Machine Learning**](https://colab.research.google.com/drive/1eu186yspQtioJMCCDi_r0bTpCe86Vqn-?usp=sharing)

# %% [markdown]
# # **Data Pre-processing( about 80% work of any ML problem)**
#  - [**Numerical data pre-processing**](https://colab.research.google.com/drive/1CEdIxl5aw9MP9Z_qEkiU6Mo07wS_stXq?usp=sharing)
#
#  - [**Text data pre-processing**](https://colab.research.google.com/drive/1GWOuK3LmghE9JJYcX1-V_Kj2UdPS_md1?usp=sharing)

# %% [markdown]
# # **Machine Learning Algorithm**
#
# # Supervised Machine Learning Algorithms
#  - [**About Supervised Machine Learning**](https://colab.research.google.com/drive/1WHMXFxU8DK-lgTgaHFZ2oLtkpFM25bDm?usp=sharing)
#
#   # Classification
#
#   - [**Decision Tree Classification**](https://colab.research.google.com/drive/1s3FIebP6zFkoaB3MuqmzXgSdrBfXVcqR?usp=sharing)
#
#   - [**Random Forest Classifier**](https://colab.research.google.com/drive/140Rgt2a5AokZq3nxnqd9dD3MsDtPfjy1?usp=sharing)
#
#   - [**K-Nearest Neighbor(KNN)**](https://colab.research.google.com/drive/1PVVxqbyEjXDTrIq1p6ss2t9r_5rIt375?usp=sharing)
#
#   - [**Logistic regression**](https://colab.research.google.com/drive/159nL5tsYam-n6rCId9wTfYBxbAiO6NSg?usp=sharing)
#
#    # Regression
#
#   - [**Linear Regression**](https://colab.research.google.com/drive/1Nh-ivrvVp-tzlLAcKghykm4LBItf0nJz?usp=sharing)

# %% [markdown]
# # Unsupervised Machine Learning Algorithms
#  - [**About Unsupervised Machine Learning**](https://colab.research.google.com/drive/1zfsZ9IMHJ6Fgn0PgCXEX2z-zni_gwIaB?usp=sharing)
#
#   # Clustering
#
#   - [**K-Means**](https://colab.research.google.com/drive/1GK7CAjIZQGN5IqCHPV6uFR2bBSn0w4tl?usp=sharing)
#
#   - [**DBSCAN**](https://colab.research.google.com/drive/1ptxfbwWSYVfYikU8U5sEiZRGRJzKzM00?usp=sharing)
#
#   # Association Rule Mining
#
#   - [**Apriori Algorithm**](https://colab.research.google.com/drive/1G6w1gcWY2e-cHrPLQiQyXQ9RlcLiVtur?usp=sharing)

# %% [markdown]
# # Ensemble Machine Learning Algorithms
#
#   - [**Gradient Boosting**](https://colab.research.google.com/drive/19o5tPkF-FRt7SIEoQKXsmEIhYAcTTGYZ?usp=sharing)
#
#   - [**XGBoost**](https://colab.research.google.com/drive/1_1_jCK3NI8EPFHynE_ORikedF0o-WNTP?usp=sharing)

# %% [markdown]
# # **Machine Learning in its simplest form in Sklearn**
#
#  - [**All in one**](https://colab.research.google.com/drive/1l_SE-qSzdDrQtlOiT-iPiP6uPcrFl34l?authuser=1#scrollTo=NbTXxDr9zmej)

# %% [markdown]
# # **Anomaly Detection**
# - [**What is Anomaly detection**](https://colab.research.google.com/drive/1XJEVaEfNOTv9CbHmFY_KTZsaJQHxZGpx?usp=sharing)

# %% [markdown]
# # Working with Time Series Data
#
# - [**Forcasting in timeseries data using Prophet** - facebook timeseries library](https://colab.research.google.com/drive/1zhxIu9uW6t5rGB0HrxiJAfQc8GyzCB4e?usp=sharing)
#
# - [**Anomaly detection in timeseries data using Prophet**](https://colab.research.google.com/drive/10QCXtMK1MPLXOTeJqrgwWRSIxmX1vCz-?usp=sharing)
#
# - [**Anomaly detection in timeseries data using Isolation Forest**](https://colab.research.google.com/drive/1tGs0QqBfIU52He0aE7B2TCCitUY7npOu?usp=sharing)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Computer Vision**
#
#  - [**Object Detection using ImageAI**](https://colab.research.google.com/drive/132on5aco2npyfT3ZSONF3pkVMz_V3Vdf?usp=sharing)
#
#  - [**Custom Object Detection using Tensorflow**](https://colab.research.google.com/drive/1b9zZRc_Rs9N4GwoSn_BNmE392L4hkPYO?usp=sharing)

# %% [markdown]
# # **Autoencoder** (Neural Network)
#
#  - [**What is autoencoder**](https://colab.research.google.com/drive/1lyEW9i-3T42Z8oGlfXf1rCf3VjrZ7Ng0?usp=sharing)
#
# # Autoencoder Application - Anomaly Detection
#
#  - [**Anomaly Detection in ECG**](https://colab.research.google.com/drive/1M8Caxvf_fsk12-yAUNXQJSDvpuvpm9jt?usp=sharing)
#
#  - [**Anomaly Detection in Sensor**](https://colab.research.google.com/drive/1LN-cqASbOuKxQ-1OnMVU5_RVmln4HLVQ?usp=sharing)
#
#  -[**Anomaly Detection in Credit Card Transaction**](https://colab.research.google.com/drive/18xa9RaPVHGgskWs1zNZgdIPJ1z_ZFrq9?usp=sharing)

# %% [markdown]
# # **Natural Language Processing(NLP)**
#
#  - [**Common text data pre-processing**](https://colab.research.google.com/drive/1GWOuK3LmghE9JJYcX1-V_Kj2UdPS_md1?usp=sharing)
#
#  - [**ABC of NLP**](https://colab.research.google.com/drive/1ncpqhv6kaykD4aShSk_OBtNbJ8xv1b1q?usp=sharing)
#
#   Word Encoding(Tokenization,Sequencing,Padding), Word Embedding and Sentiment Classifier on IMDB using TensorFlow
#  - [**Web Scraping**](https://colab.research.google.com/drive/1Z-O1eb4v0uPWdZ6mczi1TWth7-oMV-LN?usp=sharing)
#
#  - [**Sentiment Analysis(LSTM)**](https://colab.research.google.com/drive/1xCyvpx_1O91TrDkhuSu2NmoGW9h8aym6?usp=sharing)
#
#  - [**Transformer**](https://colab.research.google.com/drive/1IKsKGWlv95D0zj8BQAparlFT6XSKqFDk?usp=sharing)
#
# - [**BERT based on Transformer, Chatbot using BERT pre-trained model for Q&A**](https://colab.research.google.com/drive/1U3D7SI0B-epccNQg_3P-1bykmzk7jKec?usp=sharing)
#
# - [**How to use Transformer pre-trained model from Huggingface model hub**](https://colab.research.google.com/drive/1mupzdy9-jpIFLra4DDZEO-Tt8luqhOOy?usp=sharing)
#
# - [**Semantic Search using Sentence Embedding**](https://colab.research.google.com/drive/1-R7Spq5dtZG7VtZ7loM-o0BEI517w8Ks?usp=sharing)

# %% [markdown]
# # **ML models Performance Evaluation Techniques**
#  - [**Performance Metrics for Classification**](https://colab.research.google.com/drive/159nL5tsYam-n6rCId9wTfYBxbAiO6NSg?usp=sharing)
#
# # **ML models Performance Improvement Techniques**
#  - [**Bias & Variance**](https://colab.research.google.com/drive/1ggr1kCuLK-JRQYoroZSEqj_mgD8S-laz?usp=sharing)
#
#  - [**Cross-Validation(K-fold)**](
# https://colab.research.google.com/drive/1Kds6ElCPf4eLfT7Ik0Et8eaSwupXpfn9?usp=sharing )
#
#  - [**Hyperparameter tuning**](
# https://colab.research.google.com/drive/1DfOirqw5CAsYIxw-J2RXvak6ASsWqA3o?usp=sharing)

# %% [markdown]
# # **Microservices**
# Web Framework to deploy ML model on Web Server and use as web API
#   - [**FastAPI**](https://colab.research.google.com/drive/1PldS2HrcAWADg5tDQzlDtDccgY0DdSUR?usp=sharing)
#
#   - [**Flask**](https://colab.research.google.com/drive/1eVkHg--VW8uUAuym_joYCS2WW-0j_mS0?usp=sharing)

# %% [markdown]
# # **Working with Spark/PySpark**
# PySpark is an interface for Apache Spark in Python
#   - [**PySpark and It's Inbuilt Data Exploration & Pre-processing methods**](https://colab.research.google.com/drive/1pLo24OY6nYqh0sSDDo1iTtVqD9LcayIs?usp=sharing)
#   - [**Data Exploration & Transformation example**](https://colab.research.google.com/drive/1HXoGn5ddjgviNhvg796w7gHEdQ8QWoXw?usp=sharing)

# %% [markdown]
# # **Machine Learning Pipeline**
# In this this section we have covered how to create end-to-end ML pipelines through various tools & frameworks.
#
#   - [**ML Pipeline using PySpark**](https://colab.research.google.com/drive/1HXoGn5ddjgviNhvg796w7gHEdQ8QWoXw?usp=sharing)
#   - [**Data pipeline using Apache Beam**](https://colab.research.google.com/drive/11GF3XLUlkhhNqxt3V0kFqBgmrHm2wNhH?usp=sharing)
#   - [**ML Pipeline using Kubeflow**](https://colab.research.google.com/drive/1atXHBWcbmIWrId-ofQpAaOQr96z1ws54?usp=sharing)

# %% [markdown]
# # **Pipeline Orchestrators**
# In this this section we have covered how to create end-to-end ML pipelines through various tools & frameworks.
#
#   - [**Apache Beam**](https://colab.research.google.com/drive/11GF3XLUlkhhNqxt3V0kFqBgmrHm2wNhH?usp=sharing)
#   - [**Kubeflow**](https://colab.research.google.com/drive/1atXHBWcbmIWrId-ofQpAaOQr96z1ws54?usp=sharing)

# %% [markdown]
# # **MLOps**
# In this section we have covered MLOps and Open source tools for MLOps.
#
#   - [**What is MLOps**](https://colab.research.google.com/drive/151tpVSSrCl0ioNRxRKGLnZYZ5r8wVuqJ?usp=sharing)
#   - [**MLOps with TFX**](https://colab.research.google.com/drive/1E9bUZPQo0GkLVN0hXwXimyv0pxlxSXeZ?usp=sharing)
#   - [**MLflow**](https://colab.research.google.com/drive/17x3JS-uQmbBE4fG2T6Iu9k8XpeaQpXHu?usp=share_link)
